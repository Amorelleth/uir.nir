# %%
from sklearn.pipeline import Pipeline
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from numpy import std
from numpy import mean
from mealpy.swarm_based import AO, HGS, SSA, MRFO, HHO
from matplotlib import pyplot
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, auc
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
import numpy as np
import pandas as pd

enron = pd.read_csv(f'./input/enron/messages.csv').fillna(' ')
X_enron = np.array(enron['message'])
y_enron = np.array(enron['label'])

ling_spam = pd.read_csv(f'./input/ling_spam/messages.csv').fillna(' ')
X_ling_spam = np.array(ling_spam['message'])
y_ling_spam = np.array(ling_spam['label'])

spam_assasin = pd.read_csv(
    f'./input/spam_assasin/messages.csv').fillna(' ')
X_spam_assasin = np.array(spam_assasin['message'])
y_spam_assasin = np.array(spam_assasin['label'])

X2, y2 = X_ling_spam, y_ling_spam
X, y = X_enron, y_enron

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
print(len(X_train))
# tokenization
cv = TfidfVectorizer(stop_words=stopwords.words('english'))
X_train = cv.fit_transform(X_train)
X_test = cv.transform(X_test)

# tuned_parameters = {
#     'epsilon': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
#     'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
#     'tol': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]
# }

clf = SVC(random_state=0)
# model = RandomizedSearchCV(clf, tuned_parameters,
#                            scoring='accuracy', random_state=0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(accuracy_score(y_test, y_pred))

X2 = cv.transform(X2)
y2_pred = clf.predict(X2)

print(cv.transform(['wholes and their parts castel maretsch june bolzano italy june registration bill lawvere categorical analyses of the whole part relation coffee break john bell whole and part in mathematics lunch steve vickers w p in semantics for programming languages coffee break colin mclarty w p in foundations of mathematics carlo cellucci w p in logical analysis june gonzalo reyes a category theoretic approach to aristotle s term logic with special reference to mass nouns ettore casari on husserl s theory of wholes and parts coffee break john mayberry the classical notion of number and the modern notion of set lunch niles eldredge hierarchical biological systems coffee break alberto peruzzi wholes and their parts in semantics and epistemology local global and internal external roberto poli wholes and their parts the ontological stance june basil hiley w p in mechanics and cosmology ron langacker wholes and their parts in natural language coffee break alf zimmer w p in gestalt psychology lunch ellis d cooper wholes and parts in quale mechanics holger schmid schnbein in resonant physiological systems the whole is less complicated than the sum of its parts irina dobronravova parts and elements of the wholes in synergetics coffee break nili mandelblit the notion of dynamic unit conceptual developments in cognitive science anthony atkinson wholes and their parts in cognitive psychology lawrence d roberts sentential meaning and its parts frederik stjernfeld mereology and semiotics ariel meirav plato s theaetetus and the notion of a gestalt further information and abstracts of some of the talks are available at the imc web site http www soc unitn it dsrs imc imc htm roberto poli department of sociology and social research verdi street trento italy tel fax e mail poli risc gelso unitn it axiomathes http www soc unitn it dsrs axiomathes axiomathes htm imc http www soc unitn it dsrs imc imc htm']))
print(accuracy_score(y2, y2_pred))
