# %%
import csv
import numpy as np
import pandas as pd

# %%
enron = pd.read_csv(f'./input/enron/messages.csv').fillna(' ')
X_enron = np.array(enron['message'])
y_enron = np.array(enron['label'])

# %%
ling_spam = pd.read_csv(f'./input/ling_spam_copy/messages.csv').fillna(' ')
X_ling_spam = np.array(ling_spam['message'])
y_ling_spam = np.array(ling_spam['label'])

# %%
spam_assasin = pd.read_csv(f'./input/spam_assasin_copy/messages.csv').fillna(' ')
X_spam_assasin = np.array(spam_assasin['message'])
y_spam_assasin = np.array(spam_assasin['label'])

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, auc
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve
from sklearn.linear_model import SGDClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.calibration import CalibratedClassifierCV
from nltk.corpus import stopwords
from matplotlib import pyplot

# %%
from mealpy.swarm_based import AO, HGS, SSA, MRFO, HHO

def resolve_dataset(name):
    if (name == 'enron'):
        return [X_enron, y_enron]
    elif (name == 'ling_spam'):
        return [X_ling_spam, y_ling_spam]
    elif (name == 'spam_assasin'):
        return [X_spam_assasin, y_spam_assasin]
    else:
        return
    
def resolve_clf(alg):
    if alg == 'AO':
        return AO.OriginalAO
    elif alg == 'HGS':
        return HGS.OriginalHGS
    elif alg == 'SSA':
        return SSA.OriginalSSA
    elif alg == 'MRFO':
        return MRFO.BaseMRFO
    elif alg == 'HHO':
        return HHO.BaseHHO


def test_bio_alg(clf, obj_function):
    problem = {
        'obj_func': obj_function,
        'lb': [0.0001, 0.0001, 0.0001],
        'ub': [1000, 1000, 1000],
        'minmax': 'max',
        'verbose': True,
    }
    model = clf(problem, epoch=10, pop_size=40)
    model.solve()
    return model.g_best

# %%
def get_best(alg, dataset):
    [X, y] = resolve_dataset(dataset)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

    # tokenization
    cv = TfidfVectorizer(stop_words=stopwords.words('english'))
    X_train = cv.fit_transform(X_train)
    X_test = cv.transform(X_test)

    if (alg == 'RSCV'):
        tuned_parameters = {
            'epsilon': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
            'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
            'tol': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]
        }
        
        sgd = SGDClassifier(random_state=0, early_stopping=True)
        clf = RandomizedSearchCV(estimator=sgd, param_distributions=tuned_parameters, n_iter = 100, random_state = 42, verbose=1, n_jobs=-1, scoring='roc_auc')
        clf.fit(X_train, y_train)
        params = clf.best_params_
        
        return [params['alpha'], params['epsilon'], params['tol']]
    
    elif alg == "DEFAULT": return [0.0001, 0.1, 1e-3]

    def obj_function(solution):
        alpha, epsilon, tol = solution
        clf = SGDClassifier(random_state=0, early_stopping=True, alpha=alpha, epsilon=epsilon, tol=tol)
        clf.fit(X_train, y_train)
        return roc_auc_score(y_test, clf.decision_function(X_test))

    clf = resolve_clf(alg)
    best_params_ = test_bio_alg(clf, obj_function)

    return best_params_[0]

# %%
def test(train, test, alg):
    [X, y] = resolve_dataset(train)
    [X2, y2] = resolve_dataset(test)

    params = get_best(alg, train)

    # split dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

    # tokenization
    cv = TfidfVectorizer(stop_words=stopwords.words('english'))
    X_train = cv.fit_transform(X_train)
    X_test = cv.transform(X_test)

    clf = SGDClassifier(random_state=0, early_stopping=True, alpha=params[0], epsilon=params[1], tol=params[2])
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)

    print(f'\nLearned with {train} - tested with {test}')
    print(f'Params: {params} provided by {alg}\n')
    print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
    print(f'Precision: {precision_score(y_test, y_pred)}')
    print(f'Recall: {recall_score(y_test, y_pred)}')
    print(f'F1-score: {f1_score(y_test, y_pred)}\n')

    X2_ = cv.transform(X2)

    y_score = clf.decision_function(X_train)
    y_test_score = clf.decision_function(X_test)
    y2_score = clf.decision_function(X2_)
    y2_pred = clf.predict(X2_)

    print(f'Pred Accuracy: {accuracy_score(y2, y2_pred)}')
    print(f'Pred Precision: {precision_score(y2, y2_pred)}')
    print(f'Pred Recall: {recall_score(y2, y2_pred)}')
    print(f'Pred F1-score: {f1_score(y2, y2_pred)}')
    print(f'Pred ROC aut score: {roc_auc_score(y2, y2_score)}')

    ns_probs = [0 for _ in range(len(y2))]
    ns_auc = roc_auc_score(y2, ns_probs)
    y2_auc = roc_auc_score(y2, y2_score)
    y_auc = roc_auc_score(y_train, y_score)
    y_test_auc = roc_auc_score(y_test, y_test_score)
    
    print(f'No Skill: ROC AUC={ns_auc}')
    print(f'Applied: ROC AUC={y2_auc}')
    print(f'Trained: ROC AUC={y_auc}')
    print(f'Trained: ROC AUC={y_test_auc}')
    
    ns_fpr, ns_tpr, _ = roc_curve(y2, ns_probs)
    y2_fpr, y2_tpr, _ = roc_curve(y2, y2_score)
    y_fpr, y_tpr, _ = roc_curve(y_train, y_score)
    y_test_fpr, y_test_tpr, _ = roc_curve(y_test, y_test_score)
    
    pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='Без навыков')
    pyplot.plot(y2_fpr, y2_tpr, marker='.', label='Проверка')
    pyplot.plot(y_fpr, y_tpr, marker='.', label='train')
    pyplot.plot(y_test_fpr, y_test_tpr, marker='.', label='test')
    
    pyplot.xlabel('Ошибка первого рода')
    pyplot.ylabel('Чувствительность')
    pyplot.legend()
    pyplot.show()

# %%
test(train='enron', test='ling_spam', alg='DEFAULT')
# Out:
# Learned with enron - tested with ling_spam
# Params: [0.0001, 0.1, 0.001] provided by DEFAULT
#
# Accuracy: 0.9855261596867956
# Precision: 0.9760343658150576
# Recall: 0.996307408262174
# F1-score: 0.9860666971219735
#
# Pred Accuracy: 0.7442827442827443
# Pred Precision: 0.664796633941094
# Pred Recall: 0.9854469854469855
# Pred F1-score: 0.7939698492462312
# Pred ROC aut score: 0.9501601393493286
# No Skill: ROC AUC=0.5
# Trained: ROC AUC=0.9997838779008883
# Trained: ROC AUC=0.9987068942202285

# %%
test(train='enron', test='ling_spam', alg='RSCV')
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Learned with enron - tested with ling_spam
# Params: [0.0001, 0.001, 0.001] provided by RSCV
#
# Accuracy: 0.9899157669948986
# Precision: 0.9828532235939643
# Recall: 0.9976792759340914
# F1-score: 0.9902107566509271
#
# Pred Accuracy: 0.7297297297297297
# Pred Precision: 0.6507503410641201
# Pred Recall: 0.9916839916839917
# Pred F1-score: 0.785831960461285
# Pred ROC aut score: 0.9514006249972986
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9514006249972986

# %%
test(train='enron', test='ling_spam', alg='MRFO')
# Out:
# > Epoch: 1, Current best: 0.9985610892986765, Global best: 0.9985610892986765, Runtime: 5.72204 seconds
# > Epoch: 2, Current best: 0.9985610892986765, Global best: 0.9985610892986765, Runtime: 5.80399 seconds
# > Epoch: 3, Current best: 0.9985610892986765, Global best: 0.9985610892986765, Runtime: 5.19401 seconds
# > Epoch: 4, Current best: 0.9985610892986765, Global best: 0.9985610892986765, Runtime: 5.96847 seconds
# > Epoch: 5, Current best: 0.9985610892986765, Global best: 0.9985610892986765, Runtime: 4.90459 seconds
# > Epoch: 6, Current best: 0.9985610892986765, Global best: 0.9985610892986765, Runtime: 5.14273 seconds
# > Epoch: 7, Current best: 0.9985683018836454, Global best: 0.9985683018836454, Runtime: 5.55002 seconds
# > Epoch: 8, Current best: 0.9985768668282963, Global best: 0.9985768668282963, Runtime: 4.80813 seconds
# > Epoch: 9, Current best: 0.9985768668282963, Global best: 0.9985768668282963, Runtime: 5.31841 seconds
# > Epoch: 10, Current best: 0.9985768668282963, Global best: 0.9985768668282963, Runtime: 5.01144 seconds
#
# Learned with enron - tested with ling_spam
# Params: [1.00067853e-04 9.11903407e+02 9.25612550e+02] provided by MRFO
#
# Accuracy: 0.9877802823585241
# Precision: 0.9783746870020487
# Recall: 0.9981421272642824
# F1-score: 0.9881595585699506
#
# Pred Accuracy: 0.737006237006237
# Pred Precision: 0.6570247933884298
# Pred Recall: 0.9916839916839917
# Pred F1-score: 0.7903893951946978
# Pred ROC aut score: 0.9541409312719084
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9541409312719084

# %%
test(train='enron', test='ling_spam', alg='HGS')
# Out:
# > Epoch: 1, Current best: 0.9989077843528885, Global best: 0.9989077843528885, Runtime: 3.56071 seconds
# > Epoch: 2, Current best: 0.9989077843528885, Global best: 0.9989077843528885, Runtime: 6.55069 seconds
# > Epoch: 3, Current best: 0.9989077843528885, Global best: 0.9989077843528885, Runtime: 8.01658 seconds
# > Epoch: 4, Current best: 0.9989077843528885, Global best: 0.9989077843528885, Runtime: 8.50317 seconds
# > Epoch: 5, Current best: 0.9989077843528885, Global best: 0.9989077843528885, Runtime: 8.75178 seconds
# > Epoch: 6, Current best: 0.9989077843528885, Global best: 0.9989077843528885, Runtime: 9.66887 seconds
# > Epoch: 7, Current best: 0.9989077843528885, Global best: 0.9989077843528885, Runtime: 9.67020 seconds
# > Epoch: 8, Current best: 0.9989077843528885, Global best: 0.9989077843528885, Runtime: 10.01277 seconds
# > Epoch: 9, Current best: 0.9989077843528885, Global best: 0.9989077843528885, Runtime: 9.77145 seconds
# > Epoch: 10, Current best: 0.9989077843528885, Global best: 0.9989077843528885, Runtime: 10.04996 seconds
#
# Learned with enron - tested with ling_spam
# Params: [0.0001 0.0001 0.0001] provided by HGS
#
# Accuracy: 0.9882548344999407
# Precision: 0.9793767186067828
# Recall: 0.9978986691571329
# F1-score: 0.9885509425234185
#
# Pred Accuracy: 0.735966735966736
# Pred Precision: 0.6574202496532594
# Pred Recall: 0.9854469854469855
# Pred F1-score: 0.7886855241264559
# Pred ROC aut score: 0.9527362001374475
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9527362001374475

# %%
test(train='enron', test='ling_spam', alg='AO')
# Out:
# > Epoch: 1, Current best: 0.9987748990298303, Global best: 0.9987748990298303, Runtime: 2.91696 seconds
# > Epoch: 2, Current best: 0.9987748990298303, Global best: 0.9987748990298303, Runtime: 2.62198 seconds
# > Epoch: 3, Current best: 0.9987748990298303, Global best: 0.9987748990298303, Runtime: 2.74825 seconds
# > Epoch: 4, Current best: 0.9987748990298303, Global best: 0.9987748990298303, Runtime: 2.59142 seconds
# > Epoch: 5, Current best: 0.9987748990298303, Global best: 0.9987748990298303, Runtime: 2.65680 seconds
# > Epoch: 6, Current best: 0.9987748990298303, Global best: 0.9987748990298303, Runtime: 2.70974 seconds
# > Epoch: 7, Current best: 0.9987748990298303, Global best: 0.9987748990298303, Runtime: 7.23024 seconds
# > Epoch: 8, Current best: 0.9987748990298303, Global best: 0.9987748990298303, Runtime: 6.59460 seconds
# > Epoch: 9, Current best: 0.9987748990298303, Global best: 0.9987748990298303, Runtime: 6.22971 seconds
# > Epoch: 10, Current best: 0.9987748990298303, Global best: 0.9987748990298303, Runtime: 5.70416 seconds
#
# Learned with enron - tested with ling_spam
# Params: [0.0001 0.0001 0.0001] provided by AO
#
# Accuracy: 0.989441214853482
# Precision: 0.981460023174971
# Recall: 0.9978793590951932
# F1-score: 0.9896015889706741
#
# Pred Accuracy: 0.7162162162162162
# Pred Precision: 0.6394101876675603
# Pred Recall: 0.9916839916839917
# Pred F1-score: 0.7775061124694378
# Pred ROC aut score: 0.9499008043706589
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9499008043706589

# %%
test(train='enron', test='ling_spam', alg='HHO')
# Out:
# > Epoch: 1, Current best: 0.9988263089240049, Global best: 0.9988263089240049, Runtime: 4.47988 seconds
# > Epoch: 2, Current best: 0.9988263089240049, Global best: 0.9988263089240049, Runtime: 6.92137 seconds
# > Epoch: 3, Current best: 0.9988263089240049, Global best: 0.9988263089240049, Runtime: 5.67097 seconds
# > Epoch: 4, Current best: 0.9988263089240049, Global best: 0.9988263089240049, Runtime: 5.14576 seconds
# > Epoch: 5, Current best: 0.9988263089240049, Global best: 0.9988263089240049, Runtime: 6.45594 seconds
# > Epoch: 6, Current best: 0.9988263089240049, Global best: 0.9988263089240049, Runtime: 4.98540 seconds
# > Epoch: 7, Current best: 0.9988263089240049, Global best: 0.9988263089240049, Runtime: 5.38604 seconds
# > Epoch: 8, Current best: 0.9988263089240049, Global best: 0.9988263089240049, Runtime: 4.14934 seconds
# > Epoch: 9, Current best: 0.9988263089240049, Global best: 0.9988263089240049, Runtime: 4.19902 seconds
# > Epoch: 10, Current best: 0.9988263089240049, Global best: 0.9988263089240049, Runtime: 4.61802 seconds
#
# Learned with enron - tested with ling_spam
# Params: [1.00000000e-04 7.99121789e+00 6.82198243e+00] provided by HHO
#
# Accuracy: 0.9862379878989204
# Precision: 0.9783796085571234
# Recall: 0.9951388888888889
# F1-score: 0.9866880881340372
#
# Pred Accuracy: 0.7276507276507277
# Pred Precision: 0.6481732070365359
# Pred Recall: 0.9958419958419958
# Pred F1-score: 0.7852459016393444
# Pred ROC aut score: 0.9517636939674361
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9517636939674361

# %%
test(train='spam_assasin', test='ling_spam', alg='DEFAULT')
# Out:
# Learned with spam_assasin - tested with ling_spam
# Params: [0.0001, 0.1, 0.001] provided by DEFAULT
#
# Accuracy: 0.9947414548641542
# Precision: 0.9982332155477032
# Recall: 0.9912280701754386
# F1-score: 0.9947183098591549
#
# Pred Accuracy: 0.8128898128898129
# Pred Precision: 0.7311827956989247
# Pred Recall: 0.9896049896049897
# Pred F1-score: 0.8409893992932863
# Pred ROC aut score: 0.97025860019623
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.97025860019623

# %%
test(train='spam_assasin', test='ling_spam', alg='RSCV')
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Learned with spam_assasin - tested with ling_spam
# Params: [0.001, 0.01, 1] provided by RSCV
#
# Accuracy: 0.992988606485539
# Precision: 0.9963898916967509
# Recall: 0.989247311827957
# F1-score: 0.9928057553956834
#
# Pred Accuracy: 0.7931392931392931
# Pred Precision: 0.7149390243902439
# Pred Recall: 0.975051975051975
# Pred F1-score: 0.8249780123131046
# Pred ROC aut score: 0.9660098287956916
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9660098287956916

# %%
test(train='spam_assasin', test='ling_spam', alg='MRFO')
# Out:
# > Epoch: 1, Current best: 0.9991793150508087, Global best: 0.9991793150508087, Runtime: 1.60390 seconds
# > Epoch: 2, Current best: 0.9992315683996336, Global best: 0.9992315683996336, Runtime: 1.43004 seconds
# > Epoch: 3, Current best: 0.9994805402381522, Global best: 0.9994805402381522, Runtime: 1.42789 seconds
# > Epoch: 4, Current best: 0.9994805402381522, Global best: 0.9994805402381522, Runtime: 1.41752 seconds
# > Epoch: 5, Current best: 0.9994805402381522, Global best: 0.9994805402381522, Runtime: 1.80773 seconds
# > Epoch: 6, Current best: 0.9994805402381522, Global best: 0.9994805402381522, Runtime: 2.14051 seconds
# > Epoch: 7, Current best: 0.9994805402381522, Global best: 0.9994805402381522, Runtime: 1.62198 seconds
# > Epoch: 8, Current best: 0.9994805402381522, Global best: 0.9994805402381522, Runtime: 1.53974 seconds
# > Epoch: 9, Current best: 0.9994805402381522, Global best: 0.9994805402381522, Runtime: 1.46615 seconds
# > Epoch: 10, Current best: 0.9994805402381522, Global best: 0.9994805402381522, Runtime: 1.42689 seconds
#
# Learned with spam_assasin - tested with ling_spam
# Params: [1.43445959e-04 1.43445959e-04 5.25575292e+02] provided by MRFO
#
# Accuracy: 0.9973707274320771
# Precision: 1.0
# Recall: 0.9948892674616695
# F1-score: 0.9974380871050385
#
# Pred Accuracy: 0.7702702702702703
# Pred Precision: 0.6884057971014492
# Pred Recall: 0.9875259875259875
# Pred F1-score: 0.811272416737831
# Pred ROC aut score: 0.9609182187144765
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9609182187144765

# %%
test(train='spam_assasin', test='ling_spam', alg='HGS')
# Out:
# > Epoch: 1, Current best: 0.9967246761546592, Global best: 0.9967246761546592, Runtime: 0.68725 seconds
# > Epoch: 2, Current best: 0.9967246761546592, Global best: 0.9967246761546592, Runtime: 0.66908 seconds
# > Epoch: 3, Current best: 0.9999846373177986, Global best: 0.9999846373177986, Runtime: 0.59087 seconds
# > Epoch: 4, Current best: 0.9999846373177986, Global best: 0.9999846373177986, Runtime: 0.54817 seconds
# > Epoch: 5, Current best: 0.9999846373177986, Global best: 0.9999846373177986, Runtime: 0.52891 seconds
# > Epoch: 6, Current best: 0.9999846373177986, Global best: 0.9999846373177986, Runtime: 0.52874 seconds
# > Epoch: 7, Current best: 0.9999846373177986, Global best: 0.9999846373177986, Runtime: 0.51196 seconds
# > Epoch: 8, Current best: 0.9999846373177986, Global best: 0.9999846373177986, Runtime: 0.50275 seconds
# > Epoch: 9, Current best: 0.9999846373177986, Global best: 0.9999846373177986, Runtime: 0.51731 seconds
# > Epoch: 10, Current best: 0.9999938549271195, Global best: 0.9999938549271195, Runtime: 0.58768 seconds
#
# Learned with spam_assasin - tested with ling_spam
# Params: [0.00014243 0.00014243 0.00014243] provided by HGS
#
# Accuracy: 0.9956178790534619
# Precision: 0.9965337954939342
# Recall: 0.9948096885813149
# F1-score: 0.9956709956709957
#
# Pred Accuracy: 0.760914760914761
# Pred Precision: 0.6795422031473534
# Pred Recall: 0.9875259875259875
# Pred F1-score: 0.8050847457627118
# Pred ROC aut score: 0.9571967617705665
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9571967617705665

# %%
test(train='spam_assasin', test='ling_spam', alg='AO')
# Out:
# > Epoch: 1, Current best: 0.9987737414715102, Global best: 0.9987737414715102, Runtime: 0.81879 seconds
# > Epoch: 2, Current best: 0.9987737414715102, Global best: 0.9987737414715102, Runtime: 0.59781 seconds
# > Epoch: 3, Current best: 0.9987737414715102, Global best: 0.9987737414715102, Runtime: 0.59599 seconds
# > Epoch: 4, Current best: 0.9987737414715102, Global best: 0.9987737414715102, Runtime: 0.61135 seconds
# > Epoch: 5, Current best: 0.9987737414715102, Global best: 0.9987737414715102, Runtime: 0.67980 seconds
# > Epoch: 6, Current best: 0.9987737414715102, Global best: 0.9987737414715102, Runtime: 0.67847 seconds
# > Epoch: 7, Current best: 0.9987737414715102, Global best: 0.9987737414715102, Runtime: 0.50836 seconds
# > Epoch: 8, Current best: 0.9987737414715102, Global best: 0.9987737414715102, Runtime: 0.54198 seconds
# > Epoch: 9, Current best: 0.9987737414715102, Global best: 0.9987737414715102, Runtime: 0.65752 seconds
# > Epoch: 10, Current best: 0.9987737414715102, Global best: 0.9987737414715102, Runtime: 0.55894 seconds
#
# Learned with spam_assasin - tested with ling_spam
# Params: [0.0001 0.0001 0.0001] provided by AO
#
# Accuracy: 0.9964943032427696
# Precision: 0.9982905982905983
# Recall: 0.9948892674616695
# F1-score: 0.9965870307167236
#
# Pred Accuracy: 0.7525987525987526
# Pred Precision: 0.6694560669456067
# Pred Recall: 0.997920997920998
# Pred F1-score: 0.8013355592654424
# Pred ROC aut score: 0.9667273222366777
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9667273222366777

# %%
test(train='spam_assasin', test='ling_spam', alg='HHO')
# Out:
# > Epoch: 1, Current best: 0.9999754020231837, Global best: 0.9999754020231837, Runtime: 1.09114 seconds
# > Epoch: 2, Current best: 0.9999754020231837, Global best: 0.9999754020231837, Runtime: 1.07477 seconds
# > Epoch: 3, Current best: 0.9999784767702856, Global best: 0.9999784767702856, Runtime: 0.87003 seconds
# > Epoch: 4, Current best: 0.9999846262644897, Global best: 0.9999846262644897, Runtime: 0.85675 seconds
# > Epoch: 5, Current best: 0.9999877010115918, Global best: 0.9999877010115918, Runtime: 1.03234 seconds
# > Epoch: 6, Current best: 0.9999877010115918, Global best: 0.9999877010115918, Runtime: 1.02514 seconds
# > Epoch: 7, Current best: 0.9999877010115918, Global best: 0.9999877010115918, Runtime: 0.99187 seconds
# > Epoch: 8, Current best: 0.9999938505057959, Global best: 0.9999938505057959, Runtime: 0.84677 seconds
# > Epoch: 9, Current best: 0.9999938505057959, Global best: 0.9999938505057959, Runtime: 1.01090 seconds
# > Epoch: 10, Current best: 0.9999938505057959, Global best: 0.9999938505057959, Runtime: 1.35971 seconds
#
# Learned with spam_assasin - tested with ling_spam
# Params: [0.00012558 0.00012558 0.00012558] provided by HHO
#
# Accuracy: 0.9947414548641542
# Precision: 1.0
# Recall: 0.9894551845342706
# F1-score: 0.9946996466431096
#
# Pred Accuracy: 0.7494802494802495
# Pred Precision: 0.6694915254237288
# Pred Recall: 0.9854469854469855
# Pred F1-score: 0.7973086627417998
# Pred ROC aut score: 0.955052925946897
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.955052925946897

# %%
test(train='ling_spam', test='spam_assasin', alg='DEFAULT')
# Out:
# Learned with ling_spam - tested with spam_assasin
# Params: [0.0001, 0.1, 0.001] provided by DEFAULT
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
#
# Pred Accuracy: 0.8840420868040333
# Pred Precision: 0.8529411764705882
# Pred Recall: 0.9281017097764138
# Pred F1-score: 0.8889355448246903
# Pred ROC aut score: 0.9571708302253275
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9571708302253275

# %%
test(train='ling_spam', test='spam_assasin', alg='RSCV')
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Learned with ling_spam - tested with spam_assasin
# Params: [0.001, 0.01, 1] provided by RSCV
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
#
# Pred Accuracy: 0.8408592722490136
# Pred Precision: 0.7853211009174312
# Pred Recall: 0.9381850065760632
# Pred F1-score: 0.8549740311626048
# Pred ROC aut score: 0.9450847315595869
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9450847315595869

# %%
test(train='ling_spam', test='spam_assasin', alg='MRFO')
# Out:
# > Epoch: 1, Current best: 0.9999306037473976, Global best: 0.9999306037473976, Runtime: 0.70574 seconds
# > Epoch: 2, Current best: 0.9999306037473976, Global best: 0.9999306037473976, Runtime: 0.63161 seconds
# > Epoch: 3, Current best: 0.9999306037473976, Global best: 0.9999306037473976, Runtime: 0.64967 seconds
# > Epoch: 4, Current best: 0.9999306037473976, Global best: 0.9999306037473976, Runtime: 0.66364 seconds
# > Epoch: 5, Current best: 0.9999306037473976, Global best: 0.9999306037473976, Runtime: 0.53322 seconds
# > Epoch: 6, Current best: 0.9999306037473976, Global best: 0.9999306037473976, Runtime: 0.54783 seconds
# > Epoch: 7, Current best: 0.9999306037473976, Global best: 0.9999306037473976, Runtime: 0.57330 seconds
# > Epoch: 8, Current best: 0.9999306037473976, Global best: 0.9999306037473976, Runtime: 0.57637 seconds
# > Epoch: 9, Current best: 0.9999306037473976, Global best: 0.9999306037473976, Runtime: 0.53367 seconds
# > Epoch: 10, Current best: 0.9999306037473976, Global best: 0.9999306037473976, Runtime: 0.51943 seconds
#
# Learned with ling_spam - tested with spam_assasin
# Params: [ 46.78973856 140.41368663 205.08838814] provided by MRFO
#
# Accuracy: 0.4854771784232365
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Pred Accuracy: 0.5
# Pred Precision: 0.0
# Pred Recall: 0.0
# Pred F1-score: 0.0
# Pred ROC aut score: 0.9211628724489765
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9211628724489765
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test(train='ling_spam', test='spam_assasin', alg='HGS')
# Out:
# > Epoch: 1, Current best: 0.9999310725117178, Global best: 0.9999310725117178, Runtime: 0.37211 seconds
# > Epoch: 2, Current best: 0.9999310725117178, Global best: 0.9999310725117178, Runtime: 0.40407 seconds
# > Epoch: 3, Current best: 0.9999310725117178, Global best: 0.9999310725117178, Runtime: 0.36422 seconds
# > Epoch: 4, Current best: 1.0, Global best: 1.0, Runtime: 0.32642 seconds
# > Epoch: 5, Current best: 1.0, Global best: 1.0, Runtime: 0.42843 seconds
# > Epoch: 6, Current best: 1.0, Global best: 1.0, Runtime: 0.43101 seconds
# > Epoch: 7, Current best: 1.0, Global best: 1.0, Runtime: 0.33568 seconds
# > Epoch: 8, Current best: 1.0, Global best: 1.0, Runtime: 0.32603 seconds
# > Epoch: 9, Current best: 1.0, Global best: 1.0, Runtime: 0.32390 seconds
# > Epoch: 10, Current best: 1.0, Global best: 1.0, Runtime: 0.34834 seconds
#
# Learned with ling_spam - tested with spam_assasin
# Params: [0.00021772 0.00021772 0.00021772] provided by HGS
#
# Accuracy: 0.983402489626556
# Precision: 0.9913793103448276
# Recall: 0.9745762711864406
# F1-score: 0.982905982905983
#
# Pred Accuracy: 0.873958790004384
# Pred Precision: 0.8420208500400962
# Pred Recall: 0.920648838228847
# Pred F1-score: 0.8795811518324607
# Pred ROC aut score: 0.9481902708861358
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9481902708861358

# %%
test(train='ling_spam', test='spam_assasin', alg='AO')
# Out:
# > Epoch: 1, Current best: 1.0, Global best: 1.0, Runtime: 0.39072 seconds
# > Epoch: 2, Current best: 1.0, Global best: 1.0, Runtime: 0.50343 seconds
# > Epoch: 3, Current best: 1.0, Global best: 1.0, Runtime: 0.38769 seconds
# > Epoch: 4, Current best: 1.0, Global best: 1.0, Runtime: 0.37334 seconds
# > Epoch: 5, Current best: 1.0, Global best: 1.0, Runtime: 0.36871 seconds
# > Epoch: 6, Current best: 1.0, Global best: 1.0, Runtime: 0.35947 seconds
# > Epoch: 7, Current best: 1.0, Global best: 1.0, Runtime: 0.34043 seconds
# > Epoch: 8, Current best: 1.0, Global best: 1.0, Runtime: 0.35025 seconds
# > Epoch: 9, Current best: 1.0, Global best: 1.0, Runtime: 0.33608 seconds
# > Epoch: 10, Current best: 1.0, Global best: 1.0, Runtime: 0.34685 seconds
#
# Learned with ling_spam - tested with spam_assasin
# Params: [0.0001 0.0001 0.0001] provided by AO
#
# Accuracy: 0.995850622406639
# Precision: 1.0
# Recall: 0.9920634920634921
# F1-score: 0.9960159362549801
#
# Pred Accuracy: 0.8213502849627357
# Pred Precision: 0.7579169598874033
# Pred Recall: 0.9443226654975888
# Pred F1-score: 0.8409135272301386
# Pred ROC aut score: 0.9495547823633502
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9495547823633502

# %%
test(train='ling_spam', test='spam_assasin', alg='HHO')
# Out:
# > Epoch: 1, Current best: 0.9999306999306999, Global best: 0.9999306999306999, Runtime: 0.56042 seconds
# > Epoch: 2, Current best: 0.9999306999306999, Global best: 0.9999306999306999, Runtime: 0.57229 seconds
# > Epoch: 3, Current best: 1.0, Global best: 1.0, Runtime: 0.45925 seconds
# > Epoch: 4, Current best: 1.0, Global best: 1.0, Runtime: 0.54674 seconds
# > Epoch: 5, Current best: 1.0, Global best: 1.0, Runtime: 0.49266 seconds
# > Epoch: 6, Current best: 1.0, Global best: 1.0, Runtime: 0.51162 seconds
# > Epoch: 7, Current best: 1.0, Global best: 1.0, Runtime: 0.53478 seconds
# > Epoch: 8, Current best: 1.0, Global best: 1.0, Runtime: 0.54715 seconds
# > Epoch: 9, Current best: 1.0, Global best: 1.0, Runtime: 0.54129 seconds
# > Epoch: 10, Current best: 1.0, Global best: 1.0, Runtime: 0.54039 seconds
#
# Learned with ling_spam - tested with spam_assasin
# Params: [0.00073372 0.00073372 0.00073372] provided by HHO
#
# Accuracy: 0.995850622406639
# Precision: 1.0
# Recall: 0.9918032786885246
# F1-score: 0.9958847736625513
#
# Pred Accuracy: 0.8605874616396317
# Pred Precision: 0.8123813140903912
# Pred Recall: 0.9377466023673827
# Pred F1-score: 0.8705738705738706
# Pred ROC aut score: 0.9506430088559188
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9506430088559188

# %%
test(train='enron', test='spam_assasin', alg='DEFAULT')
# Out:
# Learned with enron - tested with spam_assasin
# Params: [0.0001, 0.1, 0.001] provided by DEFAULT
#
# Accuracy: 0.9874243682524617
# Precision: 0.9795822576859892
# Recall: 0.9954686382065348
# F1-score: 0.9874615566595695
#
# Pred Accuracy: 0.605436212187637
# Pred Precision: 0.5590763940063866
# Pred Recall: 0.997807978956598
# Pred F1-score: 0.716624685138539
# Pred ROC aut score: 0.9663649218204788
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9663649218204788

# %%
test(train='enron', test='spam_assasin', alg='RSCV')
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Learned with enron - tested with spam_assasin
# Params: [0.0001, 0.001, 0.001] provided by RSCV
#
# Accuracy: 0.98766164432317
# Precision: 0.9793483249196879
# Recall: 0.9967304997664642
# F1-score: 0.9879629629629629
#
# Pred Accuracy: 0.6137658921525647
# Pred Precision: 0.5644400297988577
# Pred Recall: 0.9964927663305567
# Pred F1-score: 0.7206721623335446
# Pred ROC aut score: 0.9683585942696861
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9683585942696861

# %%
test(train='enron', test='spam_assasin', alg='MRFO')
# Out:
# > Epoch: 1, Current best: 0.998990108160953, Global best: 0.998990108160953, Runtime: 7.42368 seconds
# > Epoch: 2, Current best: 0.998990108160953, Global best: 0.998990108160953, Runtime: 6.94429 seconds
# > Epoch: 3, Current best: 0.998990108160953, Global best: 0.998990108160953, Runtime: 8.90963 seconds
# > Epoch: 4, Current best: 0.998990108160953, Global best: 0.998990108160953, Runtime: 8.98927 seconds
# > Epoch: 5, Current best: 0.998990108160953, Global best: 0.998990108160953, Runtime: 8.64294 seconds
# > Epoch: 6, Current best: 0.998990108160953, Global best: 0.998990108160953, Runtime: 8.13688 seconds
# > Epoch: 7, Current best: 0.998990108160953, Global best: 0.998990108160953, Runtime: 9.55189 seconds
# > Epoch: 8, Current best: 0.998990108160953, Global best: 0.998990108160953, Runtime: 10.13744 seconds
# > Epoch: 9, Current best: 0.9989929232689394, Global best: 0.9989929232689394, Runtime: 10.06969 seconds
# > Epoch: 10, Current best: 0.9990097013125384, Global best: 0.9990097013125384, Runtime: 5.57180 seconds
#
# Learned with enron - tested with spam_assasin
# Params: [1.00616688e-04 5.03791825e+00 2.77738230e+02] provided by MRFO
#
# Accuracy: 0.9869498161110452
# Precision: 0.9781071835803877
# Recall: 0.9967464559609575
# F1-score: 0.9873388581952118
#
# Pred Accuracy: 0.5960105217010083
# Pred Precision: 0.5532846715328467
# Pred Recall: 0.9969311705392372
# Pred F1-score: 0.7116257236739165
# Pred ROC aut score: 0.9638131056527236
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9638131056527236

# %%
test(train='enron', test='spam_assasin', alg='HGS')
# Out:
# > Epoch: 1, Current best: 0.9991207143766268, Global best: 0.9991207143766268, Runtime: 3.29746 seconds
# > Epoch: 2, Current best: 0.9991207143766268, Global best: 0.9991207143766268, Runtime: 5.64564 seconds
# > Epoch: 3, Current best: 0.9991207143766268, Global best: 0.9991207143766268, Runtime: 6.70032 seconds
# > Epoch: 4, Current best: 0.9991207143766268, Global best: 0.9991207143766268, Runtime: 7.37796 seconds
# > Epoch: 5, Current best: 0.9991207143766268, Global best: 0.9991207143766268, Runtime: 7.46096 seconds
# > Epoch: 6, Current best: 0.9991207143766268, Global best: 0.9991207143766268, Runtime: 8.63136 seconds
# > Epoch: 7, Current best: 0.9991207143766268, Global best: 0.9991207143766268, Runtime: 8.26777 seconds
# > Epoch: 8, Current best: 0.9991207143766268, Global best: 0.9991207143766268, Runtime: 7.70439 seconds
# > Epoch: 9, Current best: 0.9991207143766268, Global best: 0.9991207143766268, Runtime: 7.61805 seconds
# > Epoch: 10, Current best: 0.9991207143766268, Global best: 0.9991207143766268, Runtime: 7.64181 seconds
#
# Learned with enron - tested with spam_assasin
# Params: [0.0001 0.0001 0.0001] provided by HGS
#
# Accuracy: 0.9882548344999407
# Precision: 0.98006416131989
# Recall: 0.9972021450221497
# F1-score: 0.9885588813128395
#
# Pred Accuracy: 0.5925032880315652
# Pred Precision: 0.5511887433284813
# Pred Recall: 0.9960543621218764
# Pred F1-score: 0.7096673434327658
# Pred ROC aut score: 0.9668275430086829
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9668275430086829

# %%
test(train='enron', test='spam_assasin', alg='AO')
# Out:
# > Epoch: 1, Current best: 0.9991782221081583, Global best: 0.9991782221081583, Runtime: 2.85680 seconds
# > Epoch: 2, Current best: 0.9991782221081583, Global best: 0.9991782221081583, Runtime: 2.56974 seconds
# > Epoch: 3, Current best: 0.9991782221081583, Global best: 0.9991782221081583, Runtime: 2.54428 seconds
# > Epoch: 4, Current best: 0.9991782221081583, Global best: 0.9991782221081583, Runtime: 2.54050 seconds
# > Epoch: 5, Current best: 0.9991782221081583, Global best: 0.9991782221081583, Runtime: 2.60848 seconds
# > Epoch: 6, Current best: 0.9991782221081583, Global best: 0.9991782221081583, Runtime: 2.53609 seconds
# > Epoch: 7, Current best: 0.9991782221081583, Global best: 0.9991782221081583, Runtime: 3.44244 seconds
# > Epoch: 8, Current best: 0.9991782221081583, Global best: 0.9991782221081583, Runtime: 3.77870 seconds
# > Epoch: 9, Current best: 0.9991782221081583, Global best: 0.9991782221081583, Runtime: 5.07706 seconds
# > Epoch: 10, Current best: 0.9991782221081583, Global best: 0.9991782221081583, Runtime: 4.72840 seconds
#
# Learned with enron - tested with spam_assasin
# Params: [1.00000000e-04 1.00000000e-04 8.33997346e+01] provided by AO
#
# Accuracy: 0.9901530430656068
# Precision: 0.9832441238073074
# Recall: 0.9974032105760151
# F1-score: 0.9902730575413101
#
# Pred Accuracy: 0.590311266988163
# Pred Precision: 0.5498306724721819
# Pred Recall: 0.9964927663305567
# Pred F1-score: 0.7086515978176149
# Pred ROC aut score: 0.962840774705019
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.962840774705019

# %%
test(train='enron', test='spam_assasin', alg='HHO')
# Out:
# > Epoch: 1, Current best: 0.9990674943344171, Global best: 0.9990674943344171, Runtime: 4.80132 seconds
# > Epoch: 2, Current best: 0.9990674943344171, Global best: 0.9990674943344171, Runtime: 6.24759 seconds
# > Epoch: 3, Current best: 0.9990674943344171, Global best: 0.9990674943344171, Runtime: 5.19544 seconds
# > Epoch: 4, Current best: 0.9990674943344171, Global best: 0.9990674943344171, Runtime: 6.11258 seconds
# > Epoch: 5, Current best: 0.9990674943344171, Global best: 0.9990674943344171, Runtime: 6.08757 seconds
# > Epoch: 6, Current best: 0.9990674943344171, Global best: 0.9990674943344171, Runtime: 5.14085 seconds
# > Epoch: 7, Current best: 0.9990714356094196, Global best: 0.9990714356094196, Runtime: 5.02227 seconds
# > Epoch: 8, Current best: 0.999088270484073, Global best: 0.999088270484073, Runtime: 4.49154 seconds
# > Epoch: 9, Current best: 0.999088270484073, Global best: 0.999088270484073, Runtime: 3.75133 seconds
# > Epoch: 10, Current best: 0.999088270484073, Global best: 0.999088270484073, Runtime: 4.31613 seconds
#
# Learned with enron - tested with spam_assasin
# Params: [1.01651396e-04 1.01651396e-04 6.82273902e+01] provided by HHO
#
# Accuracy: 0.9896784909241902
# Precision: 0.9831665150136488
# Recall: 0.9970011534025375
# F1-score: 0.9900355056694538
#
# Pred Accuracy: 0.6106970626918018
# Pred Precision: 0.5624845335313041
# Pred Recall: 0.9964927663305567
# Pred F1-score: 0.719076241695666
# Pred ROC aut score: 0.9669422853640457
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.9669422853640457

# %%
test(train='spam_assasin', test='enron', alg='DEFAULT')
# Out:
# Learned with spam_assasin - tested with enron
# Params: [0.0001, 0.1, 0.001] provided by DEFAULT
#
# Accuracy: 0.9964943032427696
# Precision: 0.99822695035461
# Recall: 0.9946996466431095
# F1-score: 0.9964601769911505
#
# Pred Accuracy: 0.6842355034850957
# Pred Precision: 0.642982379240817
# Pred Recall: 0.8543389633080956
# Pred F1-score: 0.7337434973989596
# Pred ROC aut score: 0.7975715512994421
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.7975715512994421

# %%
test(train='spam_assasin', test='enron', alg='RSCV')
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Learned with spam_assasin - tested with enron
# Params: [0.0001, 0.001, 0.001] provided by RSCV
#
# Accuracy: 0.9938650306748467
# Precision: 0.9982300884955753
# Recall: 0.9894736842105263
# F1-score: 0.9938325991189427
#
# Pred Accuracy: 0.6902565623609669
# Pred Precision: 0.651093841247024
# Pred Recall: 0.8441467676179383
# Pred F1-score: 0.7351576171032943
# Pred ROC aut score: 0.7996852568303068
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.7996852568303068

# %%
test(train='spam_assasin', test='enron', alg='MRFO')
# Out:
# > Epoch: 1, Current best: 0.9999846247516899, Global best: 0.9999846247516899, Runtime: 1.14504 seconds
# > Epoch: 2, Current best: 0.999993849900676, Global best: 0.999993849900676, Runtime: 0.84573 seconds
# > Epoch: 3, Current best: 0.999993849900676, Global best: 0.999993849900676, Runtime: 0.92492 seconds
# > Epoch: 4, Current best: 0.999993849900676, Global best: 0.999993849900676, Runtime: 0.75552 seconds
# > Epoch: 5, Current best: 1.0, Global best: 1.0, Runtime: 0.62185 seconds
# > Epoch: 6, Current best: 1.0, Global best: 1.0, Runtime: 0.59874 seconds
# > Epoch: 7, Current best: 1.0, Global best: 1.0, Runtime: 0.53388 seconds
# > Epoch: 8, Current best: 1.0, Global best: 1.0, Runtime: 0.51021 seconds
# > Epoch: 9, Current best: 1.0, Global best: 1.0, Runtime: 0.50761 seconds
# > Epoch: 10, Current best: 1.0, Global best: 1.0, Runtime: 0.52072 seconds
#
# Learned with spam_assasin - tested with enron
# Params: [1.78238260e-04 1.00000000e+03 9.99815588e+02] provided by MRFO
#
# Accuracy: 0.9956178790534619
# Precision: 0.9982300884955753
# Recall: 0.9929577464788732
# F1-score: 0.9955869373345102
#
# Pred Accuracy: 0.6707103663057986
# Pred Precision: 0.6306069737408524
# Pred Recall: 0.8531741409435061
# Pred F1-score: 0.7251980198019802
# Pred ROC aut score: 0.7810925111496804
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.7810925111496804

# %%
test(train='spam_assasin', test='enron', alg='HGS')
# Out:
# > Epoch: 1, Current best: 0.9992307881652144, Global best: 0.9992307881652144, Runtime: 0.39303 seconds
# > Epoch: 2, Current best: 0.9992307881652144, Global best: 0.9992307881652144, Runtime: 0.45054 seconds
# > Epoch: 3, Current best: 0.9995569339831635, Global best: 0.9995569339831635, Runtime: 0.52123 seconds
# > Epoch: 4, Current best: 0.9995753950671983, Global best: 0.9995753950671983, Runtime: 0.55586 seconds
# > Epoch: 5, Current best: 0.9995753950671983, Global best: 0.9995753950671983, Runtime: 0.61831 seconds
# > Epoch: 6, Current best: 0.9995938561512332, Global best: 0.9995938561512332, Runtime: 0.66372 seconds
# > Epoch: 7, Current best: 0.9996030866932506, Global best: 0.9996030866932506, Runtime: 0.63334 seconds
# > Epoch: 8, Current best: 0.9994523211736326, Global best: 0.9996030866932506, Runtime: 0.60953 seconds
# > Epoch: 9, Current best: 0.9996184709299464, Global best: 0.9996184709299464, Runtime: 0.58668 seconds
# > Epoch: 10, Current best: 0.9996184709299464, Global best: 0.9996184709299464, Runtime: 0.46409 seconds
#
# Learned with spam_assasin - tested with enron
# Params: [0.00012189 0.00012189 0.00012189] provided by HGS
#
# Accuracy: 0.992988606485539
# Precision: 1.0
# Recall: 0.9864864864864865
# F1-score: 0.9931972789115647
#
# Pred Accuracy: 0.6953284888032033
# Pred Precision: 0.6604484555266096
# Pred Recall: 0.8268491555037857
# Pred F1-score: 0.7343402472456422
# Pred ROC aut score: 0.8011201866813529
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.8011201866813529

# %%
test(train='spam_assasin', test='enron', alg='AO')
# Out:
# > Epoch: 1, Current best: 0.999508267256746, Global best: 0.999508267256746, Runtime: 0.33486 seconds
# > Epoch: 2, Current best: 0.999508267256746, Global best: 0.999508267256746, Runtime: 0.43138 seconds
# > Epoch: 3, Current best: 0.999508267256746, Global best: 0.999508267256746, Runtime: 0.36792 seconds
# > Epoch: 4, Current best: 0.999508267256746, Global best: 0.999508267256746, Runtime: 0.30314 seconds
# > Epoch: 5, Current best: 0.999508267256746, Global best: 0.999508267256746, Runtime: 0.30318 seconds
# > Epoch: 6, Current best: 0.999508267256746, Global best: 0.999508267256746, Runtime: 0.31438 seconds
# > Epoch: 7, Current best: 0.999508267256746, Global best: 0.999508267256746, Runtime: 0.72025 seconds
# > Epoch: 8, Current best: 0.999508267256746, Global best: 0.999508267256746, Runtime: 0.61295 seconds
# > Epoch: 9, Current best: 0.999508267256746, Global best: 0.999508267256746, Runtime: 0.57201 seconds
# > Epoch: 10, Current best: 0.999508267256746, Global best: 0.999508267256746, Runtime: 0.47230 seconds
#
# Learned with spam_assasin - tested with enron
# Params: [0.0001 0.0001 0.0001] provided by AO
#
# Accuracy: 0.9956178790534619
# Precision: 0.9966273187183811
# Recall: 0.9949494949494949
# F1-score: 0.9957877000842459
#
# Pred Accuracy: 0.6958327154085718
# Pred Precision: 0.6516380860488575
# Pred Recall: 0.8653465346534653
# Pred F1-score: 0.7434389932701209
# Pred ROC aut score: 0.8084270057852141
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.8084270057852141

# %%
test(train='spam_assasin', test='enron', alg='HHO')
# Out:
# > Epoch: 1, Current best: 0.9999569575109144, Global best: 0.9999569575109144, Runtime: 0.59582 seconds
# > Epoch: 2, Current best: 0.9999569575109144, Global best: 0.9999569575109144, Runtime: 0.58326 seconds
# > Epoch: 3, Current best: 0.9999569575109144, Global best: 0.9999569575109144, Runtime: 0.47214 seconds
# > Epoch: 4, Current best: 0.9999569575109144, Global best: 0.9999569575109144, Runtime: 0.61176 seconds
# > Epoch: 5, Current best: 0.9999569575109144, Global best: 0.9999569575109144, Runtime: 0.64274 seconds
# > Epoch: 6, Current best: 0.9999569575109144, Global best: 0.9999569575109144, Runtime: 0.54378 seconds
# > Epoch: 7, Current best: 0.9999569575109144, Global best: 0.9999569575109144, Runtime: 0.55405 seconds
# > Epoch: 8, Current best: 0.9999569575109144, Global best: 0.9999569575109144, Runtime: 0.54353 seconds
# > Epoch: 9, Current best: 0.9999569575109144, Global best: 0.9999569575109144, Runtime: 0.53532 seconds
# > Epoch: 10, Current best: 0.9999569575109144, Global best: 0.9999569575109144, Runtime: 0.56374 seconds
#
# Learned with spam_assasin - tested with enron
# Params: [1.0000000e-04 1.0000000e-04 5.0578437e+01] provided by HHO
#
# Accuracy: 0.9947414548641542
# Precision: 0.9948186528497409
# Recall: 0.9948186528497409
# F1-score: 0.9948186528497409
#
# Pred Accuracy: 0.6753670473083198
# Pred Precision: 0.6367110291210963
# Pred Recall: 0.8442632498543972
# Pred F1-score: 0.7259433607932493
# Pred ROC aut score: 0.7839092269314394
# No Skill: ROC AUC=0.5
# Applied: ROC AUC=0.7839092269314394
